# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaditya69Kumar/Student-Management-System-Part-2--IDRA/blob/main/IDRA_Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4

# %%
import csv
import os

FILENAME = "expenses.csv"

# Create file if it doesn't exist
if not os.path.exists(FILENAME):
    with open(FILENAME, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Date", "Category", "Amount", "Note"])


def add_expense():
    try:
        date = input("Enter Date (YYYY-MM-DD): ")
        category = input("Enter Category: ")

        amount = float(input("Enter Amount: "))
        if amount < 0:
            raise ValueError("Amount cannot be negative.")

        note = input("Enter Note (Optional): ")

        with open(FILENAME, "a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([date, category, amount, note])

        print("\nExpense added successfully!")

    except ValueError as e:
        print("Invalid Input:", e)


def view_expenses():
    total = 0

    with open(FILENAME, "r") as file:
        reader = csv.reader(file)
        next(reader)

        print("\n")
        print(f"{'Date':<15}{'Category':<15}{'Amount':>12}    {'Note':<20}")
        print("-" * 70)

        for row in reader:
            amount = float(row[2])
            total += amount
            print(f"{row[0]:<15}{row[1]:<15}{amount:>12.2f}    {row[3]:<20}")

        print("-" * 70)
        print(f"{'Total Expense =':<30}{total:.2f}")


def category_summary():
    summary = {}

    with open(FILENAME, "r") as file:
        reader = csv.reader(file)
        next(reader)

        for row in reader:
            category = row[1]
            amount = float(row[2])

            if category in summary:
                summary[category] += amount
            else:
                summary[category] = amount

    print("\nCategory Wise Spending")
    print("-" * 35)

    print(f"{'Category':<20}{'Amount':>12}")
    print("-" * 35)

    for category, amount in summary.items():
        print(f"{category:<20}{amount:>12.2f}")

    print("-" * 35)


def menu():
    while True:
        print("\n========== Expense Tracker ==========")
        print("1. Add Expense")
        print("2. View Expenses")
        print("3. Category Wise Summary")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            add_expense()

        elif choice == "2":
            view_expenses()

        elif choice == "3":
            category_summary()

        elif choice == "4":
            print("\nThank you for using Expense Tracker!")
            break

        else:
            print("Invalid Choice! Please try again.")


menu()
# Out:
# ========== Expense Tracker ==========
# 1. Add Expense
# 2. View Expenses
# 3. Category Wise Summary
# 4. Exit
# Enter your choice: 1
# Enter Date (YYYY-MM-DD): 2026-07-19
# Enter Category: Food
# Enter Amount: 200
# Enter Note (Optional): Lunch
#
# Expense added successfully!
#
# ========== Expense Tracker ==========
# 1. Add Expense
# 2. View Expenses
# 3. Category Wise Summary
# 4. Exit
# Enter your choice: 1
# Enter Date (YYYY-MM-DD): 2026-07-19
# Enter Category: Travel
# Enter Amount: 500
# Enter Note (Optional): Bus
#
# Expense added successfully!
#
# ========== Expense Tracker ==========
# 1. Add Expense
# 2. View Expenses
# 3. Category Wise Summary
# 4. Exit
# Enter your choice: 1
# Enter Date (YYYY-MM-DD): 2026-07-20
# Enter Category: Shopping
# Enter Amount: 1200
# Enter Note (Optional): Shoes
#
# Expense added successfully!
#
# ========== Expense Tracker ==========
# 1. Add Expense
# 2. View Expenses
# 3. Category Wise Summary
# 4. Exit
# Enter your choice: 2
#
#
# ...
